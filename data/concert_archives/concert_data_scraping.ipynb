# %%
from selenium.common.exceptions import WebDriverException, NoSuchElementException
from selenium.webdriver.common.by import By

import pandas as pd
import undetected_chromedriver as webdriver
import json
import random
import time
import csv

# %%
# Get sample list of artists to search and get their web pages
artist_list = [    
     "Coldplay",
     "Radiohead",
     "Red Hot Chili Peppers",
     "Rihanna",
     "Eminem"  
]

# %%
# Initialize webdriver

driver = webdriver.Chrome()

# %%
# Search artist name on website, pull URL to first search result
# Write page URL to file every 50 artists pulled in case bot detection kicks in

band_page = []  # List to store band page URL
for artist in artist_list:
    artist_format = artist.replace(" ", "+")
    search_query = f"https://www.concertarchives.org/bands?search={artist_format}"
    driver.get(search_query)
    
    try:
        href_element = driver.find_element(By.XPATH, "//strong/a").get_attribute("href")
        band_page.append([artist, href_element])
    except NoSuchElementException:  # Skip if no search result found
        continue
        
    if len(band_page) == 50:  # Write to file every 50 artists
        with open("concert_band_page.csv", "a") as tfile:
            writer = csv.writer(tfile)
            writer.writerows(band_page)
            
        band_page = []
        
    time.sleep(random.random() + 0.5)  # Randomly wait 0.5 - 1.5 seconds before next artist
    
# Save remaining scraped band page URLs to file
if len(band_page) != 0:
    with open("concert_band_page.csv", "a") as tfile:
        writer = csv.writer(tfile)
        writer.writerows(band_page)

# %%
band_page
# Out:
# [['Coldplay', 'https://www.concertarchives.org/bands/coldplay'],
#  ['Radiohead', 'https://www.concertarchives.org/bands/radiohead'],
#  ['Red Hot Chili Peppers',
#   'https://www.concertarchives.org/bands/red-hot-chili-peppers'],
#  ['Rihanna', 'https://www.concertarchives.org/bands/rihanna'],
#  ['Eminem', 'https://www.concertarchives.org/bands/eminem']]

# %%
# Import list of band page URLs
band_page = []
with open("concert_band_page.csv", "r") as tfile:
    reader = csv.reader(tfile)
    
    for row in reader:
        band_page.append(row)
        
band_page[:5]
# Out:
# [['Coldplay', 'https://www.concertarchives.org/bands/coldplay'],
#  ['Radiohead', 'https://www.concertarchives.org/bands/radiohead'],
#  ['Red Hot Chili Peppers',
#   'https://www.concertarchives.org/bands/red-hot-chili-peppers'],
#  ['Rihanna', 'https://www.concertarchives.org/bands/rihanna'],
#  ['Eminem',
#   'https://www.concertarchives.org/bands/eminemColdplay',
#   'https://www.concertarchives.org/bands/coldplay']]

# %%
# Initialize webdriver again if you took a break between getting
# artist URL and scraping artist page

driver = webdriver.Chrome()

# %%
# Loop through artists, get concerts info
master_df = None
is_master_df_set = False

for artist, artist_page in band_page:
    # Load page and get table HTML
    for page in range(1, 6):
        query = f"{artist_page}?page={page}"
        try:
            driver.get(query)
            table_element = driver.find_element(By.ID, "band-show-table-condensed")
            table_html = table_element.get_attribute("outerHTML")

            # Pass to Pandas, condense to one data frame
            df_list = pd.read_html(table_html)
            df = df_list[0]

            for i in range(1,len(df_list)):
                next_df = df_list[i]
                next_df.columns = df.columns  # Format columns for concat
                df = pd.concat([df, next_df])
        except:
            pass
        
        if is_master_df_set:
            master_df = pd.concat([master_df, df])
        else:
            master_df = df.copy()
    
    master_df["Artist"] = artist
    master_df.to_csv("concerts.csv", mode="a+", header=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-5677e5bb5b11> in <module>
#       3 is_master_df_set = False
#       4
# ----> 5 for artist, artist_page in band_page:
#       6     # Load page and get table HTML
#       7     for page in range(1, 6):
#
# ValueError: too many values to unpack (expected 2)

# %%
master_df
# Out:
#                                   Date  \
# 0   Jun 28, 2023 Upcoming  Buy Tickets
# 1     Show Duplicates for Jun 28, 2023
# 2   Jun 26, 2023 Upcoming  Buy Tickets
# 3   Jun 25, 2023 Upcoming  Buy Tickets
# 4      Show Duplicate for Jun 25, 2023
# 5                Jun 22, 2023 Upcoming
# 6                Jun 21, 2023 Upcoming
# 7                Jun 09, 2023 Upcoming
# 8                Jun 08, 2023 Upcoming
# 9                Jun 07, 2023 Upcoming
# 10     Show Duplicate for Jun 07, 2023
# 11  Jun 06, 2023 Upcoming  Buy Tickets
# 12    Show Duplicates for Jun 06, 2023
# 13  Jun 04, 2023 Upcoming  Buy Tickets
# 14    Show Duplicates for Jun 04, 2023
# 15  Jun 03, 2023 Upcoming  Buy Tickets
# 16    Show Duplicates for Jun 03, 2023
# 17  Jun 01, 2023 Upcoming  Buy Tickets
# 18     Show Duplicate for Jun 01, 2023
# 19  May 31, 2023 Upcoming  Buy Tickets
# 20    Show Duplicates for May 31, 2023
# 21  May 28, 2023 Upcoming  Buy Tickets
# 22  May 27, 2023 Upcoming  Buy Tickets
# 23  May 25, 2023 Upcoming  Buy Tickets
# 24  May 24, 2023 Upcoming  Buy Tickets
# 25               May 21, 2023 Upcoming
# 26               May 20, 2023 Upcoming
# 27     Show Duplicate for May 20, 2023
# 28               May 18, 2023 Upcoming
# 0                Jun 28, 2023 Upcoming
# 1                Jun 28, 2023 Upcoming
# 0                Jun 25, 2023 Upcoming
# 0   Jun 07, 2023 Upcoming  Buy Tickets
# 0                Jun 06, 2023 Upcoming
# 1                Jun 06, 2023 Upcoming
# 0                Jun 04, 2023 Upcoming
# 1                Jun 04, 2023 Upcoming
# 2                Jun 04, 2023 Upcoming
# 3                Jun 04, 2023 Upcoming
# 4                Jun 04, 2023 Upcoming
# 0                Jun 03, 2023 Upcoming
# 1                Jun 03, 2023 Upcoming
# 2                Jun 03, 2023 Upcoming
# 0                Jun 01, 2023 Upcoming
# 0                May 31, 2023 Upcoming
# 1                May 31, 2023 Upcoming
# 2                May 31, 2023 Upcoming
# 0                May 20, 2023 Upcoming
#
#                                               Concert  \
# 0                     Music of the Spheres World Tour
# 1                    Show Duplicates for Jun 28, 2023
# 2                                            Coldplay
# 3                                            Coldplay
# 4                     Show Duplicate for Jun 25, 2023
# 5                     Music of the Spheres World Tour
# 6                                            Coldplay
# 7   Coldplay - Music of The Spheres World Tour Col...
# 8   Coldplay - Music of The Spheres World Tour Col...
# 9            Music Of The Spheres World Tour Coldplay
# 10                    Show Duplicate for Jun 07, 2023
# 11                                           Coldplay
# 12                   Show Duplicates for Jun 06, 2023
# 13                                           Coldplay
# 14                   Show Duplicates for Jun 04, 2023
# 15                                           Coldplay
# 16                   Show Duplicates for Jun 03, 2023
# 17                                           Coldplay
# 18                    Show Duplicate for Jun 01, 2023
# 19                                           Coldplay
# 20                   Show Duplicates for May 31, 2023
# 21                               Music of the Spheres
# 22           Music Of The Spheres World Tour Coldplay
# 23                                           Coldplay
# 24                    Music of the Spheres World Tour
# 25                                           Coldplay
# 26               Music Of The Spheres World Tour 2023
# 27                    Show Duplicate for May 20, 2023
# 28                                           Coldplay
# 0                                Music of the spheres
# 1                                            Coldplay
# 0                                            Coldplay
# 0                                            Coldplay
# 0                           Music Of The Spheres Tour
# 1          Coldplay - Music of the Spheres World Tour
# 0            Music Of The Spheres World Tour Coldplay
# 1                  Music Of The Spheres Tour Coldplay
# 2                                            Coldplay
# 3                                            Coldplay
# 4                                            Coldplay
# 0                                Music of the spheres
# 1             Music Of The Spheres Word Tour Coldplay
# 2                                            Coldplay
# 0                                            Coldplay
# 0                    Music of Spheres World Tour 2023
# 1                                            Coldplay
# 2                                            Coldplay
# 0                                            Coldplay
#
#                                Venue                             Location  \
# 0                    Stadio San Siro               Milan, Lombardy, Italy
# 1   Show Duplicates for Jun 28, 2023     Show Duplicates for Jun 28, 2023
# 2                    Stadio San Siro               Milan, Lombardy, Italy
# 3                    Stadio San Siro               Milan, Lombardy, Italy
# 4    Show Duplicate for Jun 25, 2023      Show Duplicate for Jun 25, 2023
# 5      Stadio Diego Armando Maradona                        Naples, Italy
# 6      Stadio Diego Armando Maradona                        Naples, Italy
# 7                     Ullevi Stadium  Gothenburg, Västra Götaland, Sweden
# 8                     Ullevi Stadium  Gothenburg, Västra Götaland, Sweden
# 9               Principality Stadium       Cardiff, Wales, United Kingdom
# 10   Show Duplicate for Jun 07, 2023      Show Duplicate for Jun 07, 2023
# 11              Principality Stadium       Cardiff, Wales, United Kingdom
# 12  Show Duplicates for Jun 06, 2023     Show Duplicates for Jun 06, 2023
# 13                    Etihad Stadium  Manchester, England, United Kingdom
# 14  Show Duplicates for Jun 04, 2023     Show Duplicates for Jun 04, 2023
# 15                    Etihad Stadium  Manchester, England, United Kingdom
# 16  Show Duplicates for Jun 03, 2023     Show Duplicates for Jun 03, 2023
# 17                    Etihad Stadium  Manchester, England, United Kingdom
# 18   Show Duplicate for Jun 01, 2023      Show Duplicate for Jun 01, 2023
# 19                    Etihad Stadium  Manchester, England, United Kingdom
# 20  Show Duplicates for May 31, 2023     Show Duplicates for May 31, 2023
# 21    Estadi Olimpico Lluis Companys          Barcelona, Catalonia, Spain
# 22                    Estadi Olímpic          Barcelona, Catalonia, Spain
# 23     Estadi Olímpic Lluís Companys          Barcelona, Catalonia, Spain
# 24     Estadi Olímpic Lluís Companys          Barcelona, Catalonia, Spain
# 25                   Coimbra Stadium           Coimbra, Coimbra, Portugal
